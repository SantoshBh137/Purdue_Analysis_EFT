# %%
import ObservablePlotter  # replace with actual filename if needed
import importlib
importlib.reload(ObservablePlotter)

from ObservablePlotter import ObservablePlotter

# %%
file_dict = {
    "SM (ctGRe=0)": "EFT_SM_files/eft_ctgRe0.root",
    "EFT (ctGRe=2)": "EFT_SM_files/eft_ctgRe2.root"
}

#['ttbar_pt', 'ttbar_phi', 'ttbar_rapidity', 'ttbar_eta','ttbar_delta_phi', 'ttbar_delta_eta', 'ttbar_delta_rapidity',
# 'ttbar_mass', 'llbar_pt', 'll_cHel', 'llbar_phi','llbar_rapidity', 'llbar_delta_phi', 'llbar_delta_eta','llbar_delta_rapidity', 'llbar_mass']
#['b1k', 'b2k', 'b1j', 'b2j', 'b1r', 'b2r', 'b1q', 'b2q', 'b1n', 'b2n', 'c_kk', 'c_rr', 'c_nn', 'c_kj', 'c_rq', 'c_rk', 'c_kr', 'c_nr', 'c_rn',
# 'c_nk', 'c_kn', 'c_rj', 'c_jr']

#The good observables to choose for features vectors are 
plotter = ObservablePlotter(file_dict)
plotter.plot("ttbar_mass", step=0, include_uncertainty=False, bins=100)
plotter.plot("ttbar_mass", step=8, include_uncertainty=False, bins=100)
plotter.plot("c_nn", step=0, include_uncertainty=False, bins=20)
plotter.plot("c_nn", step=8, include_uncertainty=False, bins=20)
#plotter.plot("ttbar_mass", step=0, include_uncertainty=False, bins=60, save_name="ttbar_mass_plot")
