# %%
import ObservablePlotter  # replace with actual filename if needed
import importlib
importlib.reload(ObservablePlotter)

from ObservablePlotter import ObservablePlotter

# %%
import numpy as np
import matplotlib.pyplot as plt
file_dict = {
    "SM (ctGRe=0)": "EFT_SM_files/EFT_reweightedSM_ctgRe0.root",
    "EFT (ctGRe=2)": "EFT_SM_files/EFT_ctgRe2.root"
}

binning_dict = {
    "ttbar_mass": np.linspace(300, 1500, 60),
    "c_kk": np.linspace(-1, 1, 40),
    "c_rr": np.linspace(-1, 1, 40),
    "c_nn": np.linspace(-1, 1, 40),
    "llbar_delta_phi":np.linspace(0, 1, 40),
    "ll_cHel": np.linspace(-1, 1, 40),
}

plotter = ObservablePlotter(file_dict)
plotter.plot("ttbar_mass", step=0, include_uncertainty=False, binning_dict=binning_dict, save_name="GEN_mttbar")
plotter.plot("ttbar_mass", step=8, include_uncertainty=False, binning_dict=binning_dict, save_name="RECO_mttbar")
plotter.plot("c_kk", step=0, include_uncertainty=False, binning_dict=binning_dict, save_name="GEN_ckk")
plotter.plot("c_kk", step=8, include_uncertainty=False, binning_dict=binning_dict, save_name="RECO_ckk")
plotter.plot("c_rr", step=0, include_uncertainty=False, binning_dict=binning_dict, save_name="GEN_crr")
plotter.plot("c_rr", step=8, include_uncertainty=False, binning_dict=binning_dict, save_name="RECO_crr")
plotter.plot("c_nn", step=0, include_uncertainty=False, binning_dict=binning_dict, save_name="GEN_cnn")
plotter.plot("c_nn", step=8, include_uncertainty=False, binning_dict=binning_dict, save_name="RECO_cnn")
plotter.plot("ll_cHel", step=0, include_uncertainty=False, binning_dict=binning_dict, save_name="GEN_cosphi")
plotter.plot("ll_cHel", step=8, include_uncertainty=False, binning_dict=binning_dict, save_name="RECO_cosphi")
plotter.plot("llbar_delta_phi", step=0, include_uncertainty=False, binning_dict=binning_dict, save_name="GEN_deltaphi")
plotter.plot("llbar_delta_phi", step=8, include_uncertainty=False, binning_dict=binning_dict, save_name="RECO_deltaphi")
# Out:
# [INFO] 'SM (ctGRe=0)' uses 'finalWeight × trueLevelWeight'
# [INFO] 'EFT (ctGRe=2)' uses 'finalWeight × trueLevelWeight'
# /depot/cms/top/bhanda25/Purdue_Analysis_EFT/Purdue_Analysis_EFT/EFT_ML/ObservablePlotter.py:135: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [INFO] 'SM (ctGRe=0)' uses 'finalWeight × eventWeight'
# [INFO] 'EFT (ctGRe=2)' uses 'finalWeight × eventWeight'
# /depot/cms/top/bhanda25/Purdue_Analysis_EFT/Purdue_Analysis_EFT/EFT_ML/ObservablePlotter.py:89: RuntimeWarning: invalid value encountered in divide
#   obs = obs_dict[label]
# [INFO] 'SM (ctGRe=0)' uses 'finalWeight × trueLevelWeight'
# [INFO] 'EFT (ctGRe=2)' uses 'finalWeight × trueLevelWeight'
# [INFO] 'SM (ctGRe=0)' uses 'finalWeight × eventWeight'
# [INFO] 'EFT (ctGRe=2)' uses 'finalWeight × eventWeight'
# [INFO] 'SM (ctGRe=0)' uses 'finalWeight × trueLevelWeight'
# ...
