# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import mplhep as hep
import awkward as ak
import os

# %%
# Directory path containing the ROOT files
directory_path = '/eos/purdue/store/user/lingqian/fullrun2_eft_minitrees/spinCorrInput_2016preVFP/Nominal'

# Define the specific files you want to include (with subdirectories)
desired_files = [
    'ee/ee_ttto2l2nu_jet_smeft_mtt_0to700_2016preVFP.root',
    'ee/ee_ttto2l2nu_jet_smeft_mtt_700to900_2016preVFP.root',
    'ee/ee_ttto2l2nu_jet_smeft_mtt_900toInf_2016preVFP.root',
    'emu/emu_ttto2l2nu_jet_smeft_mtt_0to700_2016preVFP.root',
    'emu/emu_ttto2l2nu_jet_smeft_mtt_700to900_2016preVFP.root',
    'emu/emu_ttto2l2nu_jet_smeft_mtt_900toInf_2016preVFP.root',
    'mumu/mumu_ttto2l2nu_jet_smeft_mtt_0to700_2016preVFP.root',
    'mumu/mumu_ttto2l2nu_jet_smeft_mtt_700to900_2016preVFP.root',
    'mumu/mumu_ttto2l2nu_jet_smeft_mtt_900toInf_2016preVFP.root'
]

# Construct the full paths for the desired files
file_paths = [os.path.join(directory_path, filename) for filename in desired_files]

# Open each ROOT file and extract the 'ttBar_treeVariables_step8' TTree
trees = [uproot.open(file_path)['ttBar_treeVariables_step8'] for file_path in file_paths]

# Concatenate the TTrees from all files into a single TTree
file = uproot.concatenate(trees)

# %%
# Directory path containing the ROOT files
directory_path_jason = '/eos/purdue/store/user/jthieman/2016preVFP/spinCorrInput_2016preVFP_January2023/Nominal/'

# Define the specific files you want to include (with subdirectories)
desired_files_jason = [
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_0.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_1.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_2.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_3.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_4.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_5.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_6.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_7.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_8.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_9.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_10.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_11.root',
    'emu/emu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_0.root',
    'emu/emu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_1.root',
    'emu/emu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_2.root',
    'emu/emu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_3.root',
    'emu/emu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_4.root',
    'emu/emu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_5.root',
    'emu/emu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_6.root',
    'emu/emu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_7.root',
    'emu/emu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_8.root',
    'emu/emu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_9.root',
    'emu/emu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_10.root',
    'emu/emu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_11.root',
    'mumu/mumu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_0.root',
    'mumu/mumu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_1.root',
    'mumu/mumu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_2.root',
    'mumu/mumu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_3.root',
    'mumu/mumu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_4.root',
    'mumu/mumu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_5.root',
    'mumu/mumu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_6.root',
    'mumu/mumu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_7.root',
    'mumu/mumu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_8.root',
    'mumu/mumu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_9.root',
    'mumu/mumu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_10.root',
    'mumu/mumu_ttbarsignalplustau_fromDilepton_2016ULpreVFP_11.root'
    
    
]

# Construct the full paths for the desired files
file_paths_jason = [os.path.join(directory_path_jason, filename) for filename in desired_files_jason]

# Open each ROOT file and extract the 'ttBar_treeVariables_step0' TTree
trees_jason = [uproot.open(file_path)['ttBar_treeVariables_step8'] for file_path in file_paths_jason]

# Concatenate the TTrees from all files into a single TTree
file_jason = uproot.concatenate(trees_jason)

# %%
file_jason
# Out:
# <Array [{top_pt: 97.9, top_phi: ..., ...}, ...] type='1511226 * {top_pt: fl...'>

# %%
file
# Out:
# <Array [{top_pt: 108, top_phi: ..., ...}, ...] type='1724153 * {top_pt: flo...'>

# %%
weight_sm2=file['mgWeights'][:,201]
weight_sm=file['mgWeights'][:,200]
weight_sm1=file['mgWeights'][:,199]
weights = file['eventWeight']

# %%
def plot_observables(obs, obs_sm_file, xlabel, title, weights_dict, num_bins=25):
    fig, (ax, ax_ratio) = plt.subplots(2, 1, figsize=(12, 8), gridspec_kw={'height_ratios': [3, 1]}, sharex=True)

    # Determine common bin edges based on min and max values across both datasets
    min_val = min(ak.min(obs), ak.min(obs_sm_file))
    max_val = max(ak.max(obs), ak.max(obs_sm_file))
    bin_edges = np.linspace(min_val, max_val, num_bins + 1)

    # Color cycle for different weights
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

    # Extract weights
    weight_sm = weights_dict['reweighted_SM']

    # Plot histogram for reweighted SM
    counts_reweighted, _, _ = ax.hist(obs, bins=bin_edges, label="Reweighted SM", color=colors[0], 
                                      weights=weight_sm, histtype='step', density=True)

    # Histogram for SM file (Jason) without weights
    counts_sm_file, _, _ = ax.hist(obs_sm_file, bins=bin_edges, label="SM (Jason)", color="black", 
                                   histtype='step', linestyle='dashed', density=True)

    # Compute statistical uncertainties for Jason’s SM file
    raw_counts_sm_file, _ = np.histogram(obs_sm_file, bins=bin_edges)  # Unweighted counts

    # Normalize uncertainties (Poisson errors scaled by bin width)
    bin_widths = np.diff(bin_edges)
    norm_factor_sm = np.sum(raw_counts_sm_file)  # Normalize by total counts
    stat_uncertainty_sm = np.sqrt(raw_counts_sm_file) / norm_factor_sm / bin_widths

    # Compute ratio
    bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])
    ratio_sm = np.divide(counts_sm_file, counts_reweighted, out=np.ones_like(counts_sm_file), 
                         where=counts_reweighted != 0)

    # Ensure stat_uncertainty_sm is a NumPy array
    stat_uncertainty = np.asarray(stat_uncertainty_sm)

    # Plot ratio with statistical uncertainty bars for SM
    ax_ratio.errorbar(bin_centers, ratio_sm, yerr=stat_uncertainty, fmt='o', color='black', 
                      label="SM (Jason) / Reweighted SM", capsize=3)

    # Adjust ratio plot limits
    ax_ratio.set_ylim(0.8, 1.2)

    # Labels and CMS style
    ax.set_ylabel("Normalized Events")
    ax.set_title(title)
    ax.legend(loc='best')
    plt.style.use(hep.style.CMS)

    ax_ratio.set_xlabel(xlabel)
    ax_ratio.axhline(1, color='gray', linestyle='--', linewidth=1)
    ax_ratio.set_ylabel("Ratio")

    plt.tight_layout()
    plt.show()

# %%
observables = {
    'b1k': file['b1k'],
    'b2k': file['b2k'],
    'b1j': file['b1j'],
    'b2j': file['b2j'],
    'b1r': file['b1r'],
    'b2r': file['b2r'],
    'b1q': file['b1q'],
    'b2q': file['b2q'],
    'b1n': file['b1n'],
    'b2n': file['b2n'],
    'l_pt': file['l_pt'],
    'lbar_pt': file['lbar_pt'],
    'c_kk': file['c_kk'],
    'c_rr': file['c_rr'],
    'c_nn': file['c_nn'],
    'll_cHel': file['ll_cHel'],
    'crk_ckr': file['c_rk'] + file['c_kr'],
    'eta': file['l_eta'],
}

observables_jason = {
    'b1k': file_jason['b1k'],
    'b2k': file_jason['b2k'],
    'b1j': file_jason['b1j'],
    'b2j': file_jason['b2j'],
    'b1r': file_jason['b1r'],
    'b2r': file_jason['b2r'],
    'b1q': file_jason['b1q'],
    'b2q': file_jason['b2q'],
    'b1n': file_jason['b1n'],
    'b2n': file_jason['b2n'],
    'l_pt': file_jason['l_pt'],
    'lbar_pt': file_jason['lbar_pt'],
    'c_kk': file_jason['c_kk'],
    'c_rr': file_jason['c_rr'],
    'c_nn': file_jason['c_nn'],
    'll_cHel': file_jason['ll_cHel'],
    'crk_ckr': file_jason['c_rk'] + file_jason['c_kr'],
    'eta': file_jason['l_eta'],
}

# Observable labels
observables_to_plot = {
    'b1k': ('$b_{1k}$', '$b_{1k}$'),
    'b2k': ('$b_{2k}$', '$b_{2k}$'),
    'b1j': ('$b_{1j}$', '$b_{1j}$'),
    'b2j': ('$b_{2j}$', '$b_{2j}$'),
    'b1r': ('$b_{1r}$', '$b_{1r}$'),
    'b2r': ('$b_{2r}$', '$b_{2r}$'),
    'b1q': ('$b_{1q}$', '$b_{1q}$'),
    'b2q': ('$b_{2q}$', '$b_{2q}$'),
    'b1n': ('$b_{1n}$', '$b_{1n}$'),
    'b2n': ('$b_{2n}$', '$b_{2n}$'),
    'l_pt': ('$p_T(\\ell)$', '$p_T(\\ell)$'),
    'lbar_pt': ('$p_T(\\overline{\\ell})$', '$p_T(\\overline{\\ell})$'),
    'c_kk': ('$C_{kk}$', '$C_{kk}$'),
    'c_rr': ('$C_{rr}$', '$C_{rr}$'),
    'c_nn': ('$C_{nn}$', '$C_{nn}$'),
    'll_cHel': ('$\\cos\\phi$', '$\\cos\\phi$'),
    'crk_ckr': ('$C_{rk} + C_{kr}$', '$C_{rk} + C_{kr}$'),
    'eta': ('$\\eta(\\ell)$', '$\\eta(\\ell)$'),
}

# pt > 1 GeV cut
mask_file = (observables['l_pt'] > 1) & (observables['lbar_pt'] > 1)
mask_jason = (observables_jason['l_pt'] > 1) & (observables_jason['lbar_pt'] > 1)


# Define weights dynamically after applying the mask
weights_dict = {
    'reweighted_SM': weight_sm[mask_file],  # SM weights from existing data
    #'ctgRe=-2': weight_ctg[mask],
    #'ctgRe=10': weight_ctgRe_10[mask],
}

# Apply the same mask to filter all observables
filtered_observables = {key: val[mask_file] for key, val in observables.items()}
filtered_observables_jason = {key: val for key, val in observables_jason.items()}

# Loop through and plot all observables with the filtered data
for obs_key, (xlabel, title) in observables_to_plot.items():
    plot_observables(filtered_observables[obs_key], filtered_observables_jason[obs_key], xlabel, title, weights_dict)

# %%
import numpy as np
from uncertainties import ufloat

# Original C_ij and D observables
observables = {
    r'$C_{kk}$': file_jason['c_kk'][mask_jason],
    r'$C_{nn}$': file_jason['c_nn'][mask_jason],
    r'$C_{rr}$': file_jason['c_rr'][mask_jason],
    r'$C_{kr}$': file_jason['c_kr'][mask_jason],
    r'$C_{nr}$': file_jason['c_nr'][mask_jason],
    r'$C_{rn}$': file_jason['c_rn'][mask_jason],
    r'$C_{rk}$': file_jason['c_rk'][mask_jason],
    r'$C_{kn}$': file_jason['c_kn'][mask_jason],
    r'$C_{nk}$': file_jason['c_nk'][mask_jason],
    r'$C_{kr}+C_{rk}$': file_jason['c_kr'][mask_jason] + file_jason['c_rk'][mask_jason],
    r'$C_{kn}+C_{nk}$': file_jason['c_kn'][mask_jason] + file_jason['c_nk'][mask_jason],
    r'$C_{rn}+C_{nr}$': file_jason['c_rn'][mask_jason] + file_jason['c_nr'][mask_jason],
    r'$D$': file_jason['ll_cHel'][mask_jason]  # Assuming cos(φ)
}

# Add b1/b2-type observables (with constant factor 2)
b_observables = {
    r'$b_{1k}$': file_jason['b1k'][mask_jason],
    r'$b_{2k}$': file_jason['b2k'][mask_jason],
    r'$b_{1j}$': file_jason['b1j'][mask_jason],
    r'$b_{2j}$': file_jason['b2j'][mask_jason],
    r'$b_{1r}$': file_jason['b1r'][mask_jason],
    r'$b_{2r}$': file_jason['b2r'][mask_jason],
    r'$b_{1q}$': file_jason['b1q'][mask_jason],
    r'$b_{2q}$': file_jason['b2q'][mask_jason],
    r'$b_{1n}$': file_jason['b1n'][mask_jason],
    r'$b_{2n}$': file_jason['b2n'][mask_jason],
}


# Combine all observables
observables.update(b_observables)

# Define the weights
weights = file_jason['eventWeight'][mask_jason]

# Constants
constant_factor_Cij = -4.0  
constant_factor_CijCji = -16 / np.pi  
constant_factor_D = -2
constant_factor_b = 2

def assy(cosArr, weights):
    """Compute asymmetry A for a given observable array and weights."""
    N1 = ufloat(np.sum(weights[cosArr > 0]), np.sqrt(np.sum(weights[cosArr > 0]**2)))
    N2 = ufloat(np.sum(weights[cosArr < 0]), np.sqrt(np.sum(weights[cosArr < 0]**2)))
    return N1, N2, (N1 - N2) / (N1 + N2)

# Results
asymmetry_results_jason = {}
aym = []

for obs_name, obs_data in observables.items():
    # Pick constant factor based on observable type
    if obs_name.strip('$') == 'D':
        constant_factor = constant_factor_D
    elif "+" in obs_name:
        constant_factor = constant_factor_CijCji
    elif "b_" in obs_name or "b{" in obs_name:
        constant_factor = constant_factor_b
    else:
        constant_factor = constant_factor_Cij
    
    N1, N2, A = assy(obs_data, weights)
    param_value = constant_factor * A
    asymmetry_results_jason[obs_name] = { 'parameter value': param_value }
    aym.append((A, N1, N2))

# Format results into (nominal, uncertainty)
Results_jason_powheg = {
    obs_name: (values['parameter value'].nominal_value, values['parameter value'].std_dev)
    for obs_name, values in asymmetry_results_jason.items()
}

Results_jason_powheg
# Out:
# {'$C_{kk}$': (0.34356987017358803, 0.0032904244241741014),
#  '$C_{nn}$': (0.6358690008459079, 0.0032601304140717656),
#  '$C_{rr}$': (0.09752657433900667, 0.0033013266039879805),
#  '$C_{kr}$': (-0.29698851764296746, 0.003293237474213543),
#  '$C_{nr}$': (0.002063494822232371, 0.0033022966269043628),
#  '$C_{rn}$': (-0.0026376325577399723, 0.003302295506712514),
#  '$C_{rk}$': (-0.29059860536984033, 0.0032935860870319197),
#  '$C_{kn}$': (-0.0011654579640502513, 0.0033022958664319394),
#  '$C_{nk}$': (-0.002054743744056181, 0.0033022951673244354),
#  '$C_{kr}+C_{rk}$': (-0.553056990728476, 0.004179865386028281),
#  '$C_{kn}+C_{nk}$': (-0.001110601054230888, 0.0042046139119390116),
#  '$C_{rn}+C_{nr}$': (0.0022133023443897323, 0.0042046124052989384),
#  '$D$': (-0.3934810442343622, 0.001619119393853703),
#  '$b_{1k}$': (0.3135351166088599, 0.001629859566879275),
#  '$b_{2k}$': (0.3157648069861648, 0.001629584553842402),
#  '$b_{1j}$': (-0.020855805833462658, 0.0016510804321600106),
# ...

# %%
import numpy as np
from uncertainties import ufloat

# Define the dictionary of Cij + D observables
observables = {
    r'$C_{kk}$': file['c_kk'][mask_file],
    r'$C_{nn}$': file['c_nn'][mask_file],
    r'$C_{rr}$': file['c_rr'][mask_file],
    r'$C_{kr}$': file['c_kr'][mask_file],
    r'$C_{nr}$': file['c_nr'][mask_file],
    r'$C_{rn}$': file['c_rn'][mask_file],
    r'$C_{rk}$': file['c_rk'][mask_file],
    r'$C_{kn}$': file['c_kn'][mask_file],
    r'$C_{nk}$': file['c_nk'][mask_file],
    r'$C_{kr}+C_{rk}$': file['c_kr'][mask_file] + file['c_rk'][mask_file],
    r'$C_{kn}+C_{nk}$': file['c_kn'][mask_file] + file['c_nk'][mask_file],
    r'$C_{rn}+C_{nr}$': file['c_rn'][mask_file] + file['c_nr'][mask_file],
    r'$D$': file['ll_cHel'][mask_file],
}

# Add b1/b2 observables (factor 2)
b_observables = {
    r'$b_{1k}$': file['b1k'][mask_file],
    r'$b_{2k}$': file['b2k'][mask_file],
    r'$b_{1j}$': file['b1j'][mask_file],
    r'$b_{2j}$': file['b2j'][mask_file],
    r'$b_{1r}$': file['b1r'][mask_file],
    r'$b_{2r}$': file['b2r'][mask_file],
    r'$b_{1q}$': file['b1q'][mask_file],
    r'$b_{2q}$': file['b2q'][mask_file],
    r'$b_{1n}$': file['b1n'][mask_file],
    r'$b_{2n}$': file['b2n'][mask_file],
}

# Merge both dictionaries
observables.update(b_observables)

# Define constants
constant_factor_Cij = -4.0  
constant_factor_CijCji = -16 / np.pi  
constant_factor_D = -2
constant_factor_b = 2  # for b1/b2 observables

# Final combined weights: true weight × SM reweight factor
truelevel_weight = file['eventWeight'][mask_file]
weight_sm_reweighted = weight_sm[mask_file]
final_weights = truelevel_weight * weight_sm_reweighted

def assy(cosArr, weights):
    """Compute asymmetry A for a given observable array, using final weights."""
    N1 = ufloat(np.sum(weights[cosArr > 0]), np.sqrt(np.sum(weights[cosArr > 0]**2)))
    N2 = ufloat(np.sum(weights[cosArr < 0]), np.sqrt(np.sum(weights[cosArr < 0]**2)))
    return N1, N2, (N1 - N2) / (N1 + N2)

# Store results
asymmetry_results = {}
aym = []

# Loop over observables and compute asymmetries
for obs_name, obs_data in observables.items():
    # Determine appropriate constant
    if obs_name.strip('$') == 'D':
        constant_factor = constant_factor_D
    elif "+" in obs_name:
        constant_factor = constant_factor_CijCji
    elif "b_" in obs_name or "b{" in obs_name:
        constant_factor = constant_factor_b
    else:
        constant_factor = constant_factor_Cij

    N1, N2, A = assy(obs_data, final_weights)
    param_value = constant_factor * A
    asymmetry_results[obs_name] = {'parameter value': param_value}
    aym.append((A, N1, N2))

# Convert results to (nominal, uncertainty) format
Results_reweighted = {
    obs_name: (values['parameter value'].nominal_value, values['parameter value'].std_dev)
    for obs_name, values in asymmetry_results.items()
}

Results_reweighted
# Out:
# {'$C_{kk}$': (0.3006002330180529, 0.0036302987249596766),
#  '$C_{nn}$': (0.6254588756758458, 0.0036035263491657472),
#  '$C_{rr}$': (0.058509887619962314, 0.0036415873879869273),
#  '$C_{kr}$': (-0.2906661001279673, 0.003631759419025993),
#  '$C_{nr}$': (0.001668440412143899, 0.0036418228139526504),
#  '$C_{rn}$': (0.004800522188419327, 0.0036418613165705937),
#  '$C_{rk}$': (-0.2851914156352813, 0.003632392304584022),
#  '$C_{kn}$': (-0.0042538704920793025, 0.0036418223188746544),
#  '$C_{nk}$': (0.0017456848175770349, 0.003641833786228809),
#  '$C_{kr}+C_{rk}$': (-0.5436201595485328, 0.004609905822141981),
#  '$C_{kn}+C_{nk}$': (-0.0038514641601731336, 0.004636919725724867),
#  '$C_{rn}+C_{nr}$': (0.004528895496287892, 0.004636919503603229),
#  '$D$': (-0.36304309261374096, 0.0017931569766958036),
#  '$b_{1k}$': (0.31108415131015066, 0.0017976094459963164),
#  '$b_{2k}$': (0.3102916141954052, 0.0017978779434306147),
#  '$b_{1j}$': (-0.019080740524577217, 0.0018208510903762916),
# ...

# %%
# Measured values extracted manually from image (nominal, uncertainty)
measured_data = {
    r'$b_{1k}$': (0.005, 0.023),
    r'$b_{2k}$': (0.007, 0.023),
    r'$b_{1r}$': (-0.023, 0.017),
    r'$b_{2r}$': (-0.010, 0.020),
    r'$b_{1n}$': (0.006, 0.013),
    r'$b_{2n}$': (0.017, 0.013),
    r'$b_{1j}$': (-0.016, 0.018),
    r'$b_{2j}$': (0.007, 0.019),
    r'$b_{1q}$': (0.001, 0.017),
    r'$b_{2q}$': (0.010, 0.017),
    r'$C_{kk}$': (0.300, 0.038),
    r'$C_{rr}$': (0.081, 0.032),
    r'$C_{nn}$': (0.329, 0.020),
    r'$C_{kr}+C_{rk}$': (-0.193, 0.064),
    r'$C_{rn}+C_{nr}$': (-0.004, 0.037),
    r'$C_{kn}+C_{nk}$': (-0.043, 0.041),
    r'$D$': (-0.237, 0.011)
}
observable_name_map = {
    r'$b_{1k}$': r'$b_{1k}$',
    r'$b_{2k}$': r'$b_{2k}$',
    r'$b_{1r}$': r'$b_{1r}$',
    r'$b_{2r}$': r'$b_{2r}$',
    r'$b_{1n}$': r'$b_{1n}$',
    r'$b_{2n}$': r'$b_{2n}$',
    r'$b_{1j}$': r'$b_{1j}$',
    r'$b_{2j}$': r'$b_{2j}$',
    r'$b_{1q}$': r'$b_{1q}$',
    r'$b_{2q}$': r'$b_{2q}$',
    r'$C_{kk}$': r'$C_{kk}$',
    r'$C_{rr}$': r'$C_{rr}$',
    r'$C_{nn}$': r'$C_{nn}$',
    r'$C_{kr}+C_{rk}$': r'$C_{kr}+C_{rk}$',
    r'$C_{rn}+C_{nr}$': r'$C_{rn}+C_{nr}$',
    r'$C_{kn}+C_{nk}$': r'$C_{kn}+C_{nk}$',

    r'$D$': r'$D$'
}

# %%
# Group observables into final categories (internal keys)
polarization_obs_final = [k for k in measured_data if 'b_' in k]
others = [k for k in measured_data if k not in polarization_obs_final ]

# Updated plot function with display name override
def plot_comparison_with_values_custom_labels(observable_list, xlabel):
    if not observable_list:
        print(f"Skipping plot for '{xlabel}' — no matching measured data.")
        return
    observable_list = list(reversed(observable_list))
    y_pos = np.arange(len(observable_list))
    madgraph_nom = [Results_reweighted[o][0] for o in observable_list]
    madgraph_err = [Results_reweighted[o][1] for o in observable_list]
    powheg_nom = [Results_jason_powheg.get(o, (np.nan, np.nan))[0] for o in observable_list]
    powheg_err = [Results_jason_powheg.get(o, (np.nan, np.nan))[1] for o in observable_list]
    measured_nom = [measured_data[observable_name_map[o]][0] for o in observable_list]
    measured_err = [measured_data[observable_name_map[o]][1] for o in observable_list]

    fig, ax = plt.subplots(figsize=(10, len(observable_list) * 0.6 + 2))

    # Plot points
    ax.errorbar(madgraph_nom, y_pos - 0.25, xerr=madgraph_err, fmt='s', color='magenta',
                label="MadGraph (LO, EFT_reweighted_to_SM)", capsize=3)
    ax.errorbar(powheg_nom, y_pos, xerr=powheg_err, fmt='^', color='tab:blue',
                label="POWHEGv2 (using Jason's file)", capsize=3)
    ax.errorbar(measured_nom, y_pos + 0.25, xerr=measured_err, fmt='o', color='black',
                label="Data", capsize=3)

    # Text labels
    all_vals = madgraph_nom + powheg_nom + measured_nom
    x_max = max([v for v in all_vals if not np.isnan(v)])
    label_x = x_max + 1.4*x_max

    for i, (m_val, m_err, p_val, p_err, mg_val, mg_err) in enumerate(
            zip(measured_nom, measured_err, powheg_nom, powheg_err, madgraph_nom, madgraph_err)):
        ax.text(label_x, y_pos[i] + 0.25, f"{m_val:+.4f} ± {m_err:.4f}",
                va='center', ha='left', fontsize=9, color='black')
        ax.text(label_x, y_pos[i] , f"{p_val:+.4f} ± {p_err:.4f}",
                va='center', ha='left', fontsize=8, color='tab:blue')
        ax.text(label_x, y_pos[i] - 0.25, f"{mg_val:+.4f} ± {mg_err:.4f}",
                va='center', ha='left', fontsize=8, color='magenta')

    # Use original LaTeX labels for y-axis
    display_labels = [observable_name_map[o] for o in observable_list]
    ax.set_yticks(y_pos)
    ax.set_yticklabels(display_labels)
    ax.axvline(0, color='gray', linestyle='--')
    ax.set_xlabel(xlabel)
    ax.legend(fontsize=10)
    ax.grid(True, axis='x', linestyle='--', alpha=0.5)
    ax.set_xlim(ax.get_xlim()[0], label_x + 0.15)

    plt.tight_layout()
    plt.show()

# Final plots
plot_comparison_with_values_custom_labels(polarization_obs_final, "Polarization")
plot_comparison_with_values_custom_labels(others, " Spin correlation coefficient/cross")
