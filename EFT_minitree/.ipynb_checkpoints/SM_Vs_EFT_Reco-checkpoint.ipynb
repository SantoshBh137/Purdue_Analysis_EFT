# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import mplhep as hep
import awkward as ak
import os

# %%
# Directory path containing the ROOT files
directory_path = '/eos/purdue/store/user/lingqian/fullrun2_eft_minitrees/spinCorrInput_2016preVFP/Nominal'

# Define the specific files you want to include (with subdirectories)
desired_files = [
    'ee/ee_ttto2l2nu_jet_smeft_mtt_0to700_2016preVFP.root',
    'ee/ee_ttto2l2nu_jet_smeft_mtt_700to900_2016preVFP.root',
    'ee/ee_ttto2l2nu_jet_smeft_mtt_900toInf_2016preVFP.root',
    
    #'mumu/mumu_ttto2l2nu_jet_smeft_mtt_0to700_2016preVFP.root',
    #'mumu/mumu_ttto2l2nu_jet_smeft_mtt_700to900_2016preVFP.root',
    #'mumu/mumu_ttto2l2nu_jet_smeft_mtt_900toInf_2016preVFP.root'
]

# Construct the full paths for the desired files
file_paths = [os.path.join(directory_path, filename) for filename in desired_files]

# Open each ROOT file and extract the 'ttBar_treeVariables_step8' TTree
trees = [uproot.open(file_path)['ttBar_treeVariables_step0'] for file_path in file_paths]

# Concatenate the TTrees from all files into a single TTree
file = uproot.concatenate(trees)

# %%
# Directory path containing the ROOT files
directory_path_jason = '/eos/purdue/store/user/jthieman/2016preVFP/spinCorrInput_2016preVFP_January2023/Nominal/'

# Define the specific files you want to include (with subdirectories)
desired_files_jason = [
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_0.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_1.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_2.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_3.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_4.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_10.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_11.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_12.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_13.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_14.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_15.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_16.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_17.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_18.root',
    'ee/ee_ttbarsignalplustau_fromDilepton_2016ULpreVFP_19.root'
    
]

# Construct the full paths for the desired files
file_paths_jason = [os.path.join(directory_path_jason, filename) for filename in desired_files_jason]

# Open each ROOT file and extract the 'ttBar_treeVariables_step0' TTree
trees_jason = [uproot.open(file_path)['ttBar_treeVariables_step0'] for file_path in file_paths_jason]

# Concatenate the TTrees from all files into a single TTree
file_jason = uproot.concatenate(trees_jason)

# %%
weight_sm=file['mgWeights'][:,200]
weight_ctgRe1=file['mgWeights'][:,201]
weight_ctgRe_ctu8=file['mgWeights'][:,223]
weight_ctgRe2=file['mgWeights'][:,217]
weight_ctu81=file['mgWeights'][:,207]
weight_ctu82=file['mgWeights'][:,298]
weights = file['trueLevelWeight']

# %%
import numpy as np

def predict_event_weight( c1, c2):
    """
    Predicts the event weight for given c1 and c2 values using least squares fitting.

    Parameters:
    weight (list of lists or numpy array): The event weight data.
    c1 (int or float): The value of c1 for prediction.
    c2 (int or float): The value of c2 for prediction.

    Returns:
    numpy array: Predicted event weights for each event at (c1, c2).
    """

    num_events = len(weight_sm)
    predicted = []

    for i in range(num_events):
        # Construct A matrix (per event)
        A = np.array([
            [1, 0, 0, 0, 0, 0],  # w_sm (c1=0, c2=0)
            [1, 1, 0, 1, 0, 0],  # w(c1=1, c2=0)
            [1, 0, 1, 0, 1, 0],  # w(c1=0, c2=1)
            [1, 1, 1, 1, 1, 1],  # w(c1=1, c2=1)
            [1, 2, 0, 4, 0, 0],  # w(c1=2, c2=0)
            [1, 0, 2, 0, 4, 0]   # w(c1=0, c2=2)
        ])

        # Construct w vector for this event
        w = np.array([
            weight_sm[i],
            weight_ctgRe1[i],
            weight_ctgRe_ctu8[i],
            weight_ctgRe2[i],
            weight_ctu81[i],
            weight_ctu82[i]
        ])

        # Solve for s
        s, _, _, _ = np.linalg.lstsq(A, w, rcond=None)

        # Compute predicted weight for given (c1, c2)
        A_pred = np.array([1, c1, c2, c1**2, c2**2, c1*c2])  
        w_pred = np.dot(A_pred, s)  
        predicted.append(w_pred)

    return predicted

# %%
weight_ctgRe_neg2= predict_event_weight(-2,0) #ctGRe=-2

# %%
def plot_observables(obs, obs_sm_file, xlabel, title, weights_dict, num_bins=50):
    fig, (ax, ax_ratio) = plt.subplots(2, 1, figsize=(9, 7), gridspec_kw={'height_ratios': [3, 1]}, sharex=True)

    # Determine common bin edges based on the min and max values across both SM sources
    min_val = min(ak.min(obs), ak.min(obs_sm_file))
    max_val = max(ak.max(obs), ak.max(obs_sm_file))
    bin_edges = np.linspace(min_val, max_val, num_bins + 1)

    # Color cycle for different weights
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    
    # First entry is SM (background) for ratio calculations
    sm_label = list(weights_dict.keys())[0]
    weight_sm = weights_dict[sm_label]

    # Plot histograms for each weight set
    counts_dict = {}
    for i, (label, weight) in enumerate(weights_dict.items()):
        counts, _, _ = ax.hist(obs, bins=bin_edges, label=label, color=colors[i], 
                               weights=weight, histtype='step', density=True)
        counts_dict[label] = counts

    # Add the SM file histogram without weights
    counts_sm_file, _, _ = ax.hist(obs_sm_file, bins=bin_edges, label="SM (Jason)", color="black", 
                                   histtype='step', linestyle='dashed', density=True)
    
    # Apply log scale for mttbar_mass
    if xlabel == r'$m_{t\bar{t}}$':  
        ax.set_yscale('log')
        ax.set_xlim(0, 6000)

    # Compute ratio plots (EFT/SM)
    bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])
    for i, (label, counts) in enumerate(counts_dict.items()):
        if label != sm_label:  # Skip SM in ratio plots
            ratio = np.divide(counts, counts_dict[sm_label], out=np.ones_like(counts), where=counts_dict[sm_label] != 0)
            ax_ratio.plot(bin_centers, ratio, color=colors[i], marker='o', linestyle='-', label=f"{label}/SM")

    # Adjust ratio plot limits
    ax_ratio.set_ylim(0.5, 1.5)

    # Labels and CMS style
    ax.set_ylabel("Normalized Events")
    ax.set_title(title)
    ax.legend(loc='best')
    plt.style.use(hep.style.CMS)

    ax_ratio.set_xlabel(xlabel)
    ax_ratio.axhline(1, color='gray', linestyle='--', linewidth=1)

    plt.tight_layout()
    plt.show()

# Extract observable data from the new SM file
#obs_sm_file = file_jason["observable_name"]  # Replace "observable_name" with the actual column name

# Define weights dynamically
weights_dict = {
    'reweighted_SM': weight_sm,  # SM weights from existing data
    'ctgRe=-2': weight_ctgRe_neg2  # EFT variation (if any)
}

# Call the function
#plot_observables(obs, obs_sm_file, xlabel, title, weights_dict, num_bins=50)

# %%
observables = {
    'gen_c_kk': file['gen_c_kk'],
    'gen_c_rr': file['gen_c_rr'],
    'gen_c_nn': file['gen_c_nn'],
    'gen_ll_cHel': file['gen_ll_cHel'],
    'gen_crk_ckr': file['gen_c_rk']+file['gen_c_kr'],
}

observables_jason = {
    'gen_c_kk': file_jason['gen_c_kk'],
    'gen_c_rr': file_jason['gen_c_rr'],
    'gen_c_nn': file_jason['gen_c_nn'],
    'gen_ll_cHel': file_jason['gen_ll_cHel'],
    'gen_crk_ckr': file_jason['gen_c_rk']+file_jason['gen_c_kr'],
}

# List of observables to plot
observables_to_plot = {
    'gen_c_kk': ('gen_c_kk', 'gen_c_kk'),
    'gen_c_rr': ('gen_c_rr', 'gen_c_rr'),
    'gen_c_nn': ('gen_c_nn', 'gen_c_nn'),
    'gen_ll_cHel': ('gen_$cos\phi$', 'gen_$cos\phi$'),
    'gen_crk_ckr': ('$c_{rk}+c_{kr}$', '$c_{rk}+c_{kr}$')
}

# Loop through and plot all observables
for obs_key, (xlabel, title) in observables_to_plot.items():
    plot_observables(observables[obs_key],observables_jason[obs_key], xlabel, title, weights_dict)

# %%
# Define the observables that you want to plot at reco level 
observables_reco= {
    'top_pt': file['top_pt'],
    'top_phi': file['top_phi'],
    'top_eta': file['top_eta'],
    'top_mass': file['top_mass'],
    'tbar_pt': file['tbar_pt'],
    'tbar_phi': file['tbar_phi'],
    'tbar_eta': file['tbar_eta'],
    'tbar_mass': file['tbar_mass'],
    'l_pt': file['l_pt'],
    'l_eta': file['l_eta'],
    'l_phi': file['l_phi'],
    'l_mass': file['l_mass'],
    'lbar_pt': file['lbar_pt'],
    'lbar_eta': file['lbar_eta'],
    'lbar_phi': file['lbar_phi'],
    'lbar_mass': file['lbar_mass'],
    'mttbar_mass': file['ttbar_mass'],
    'llbar_delta_phi': file['llbar_delta_phi'],
    'llbar_delta_eta': file['llbar_delta_eta'],
    'b1k': file['b1k'],
    'b2k': file['b2k'],
    'b1r': file['b1r'],
    'b2r': file['b2r'],
    'b1n': file['b1n'],
    'b2n': file['b2n'],
    'c_kk': file['c_kk'],
    'c_rr': file['c_rr'],
    'c_nn': file['c_nn'],
    'c_rk': file['c_rk'],
    'c_kr': file['c_kr'],
    'c_nr': file['c_nr'],
    'c_rn': file['c_rn'],
    'c_nk': file['c_nk'],
    'c_kn': file['c_kn'],
    'll_cHel': file['ll_cHel'],
    'crk_ckr': file['c_rk'] + file['c_kr'],
}

observables_to_plot_reco = {
    'mttbar_mass': (r'$m_{t\bar{t}}$', r''),
    'llbar_delta_phi': (r'$\Delta \phi_{\ell\ell}$', r''),
    'c_kk': (r'$\cos\theta_1^k \cos\theta_2^k$', r''),
    'c_rr': (r'$\cos\theta_1^r \cos\theta_2^r$', r''),
    'c_nn': (r'$\cos\theta_1^n \cos\theta_2^n$', r''),
    'll_cHel': (r'$\cos\phi$', r''),
    'crk_ckr': (r'$\cos\theta_1^r \cos\theta_2^k + \cos\theta_1^k \cos\theta_2^r$', r''),
    'b1k': (r'$\cos\theta_1^k$', r''),
    'b2k': (r'$\cos\theta_2^k$', r''),
    'b1r': (r'$\cos\theta_1^r$', r''),
    'b2r': (r'$\cos\theta_2^r$', r''),
    'b1n': (r'$\cos\theta_1^n$', r''),
    'b2n': (r'$\cos\theta_2^n$', r''),
}



# Loop through and plot all observables
for obs_key, (xlabel, title) in observables_to_plot_reco.items():
    plot_observables(observables_reco[obs_key], xlabel, title, weights_dict)

# %%
('top_pt', 'Top $p_T$ (GeV)', 'Top $p_T$ Distribution'),
('top_phi', 'Top $\phi$', 'Top $\phi$ Distribution'),
('top_eta', 'Top $\eta$', 'Top $\eta$ Distribution'),
('top_mass', 'Top Mass (GeV)', 'Top Mass Distribution'),
('tbar_pt', 'Anti-Top $p_T$ (GeV)', 'Anti-Top $p_T$ Distribution'),
('tbar_phi', 'Anti-Top $\phi$', 'Anti-Top $\phi$ Distribution'),
('tbar_eta', 'Anti-Top $\eta$', 'Anti-Top $\eta$ Distribution'),
('tbar_mass', 'Anti-Top Mass (GeV)', 'Anti-Top Mass Distribution'),
('l_pt', 'Lepton $p_T$ (GeV)', 'Lepton $p_T$ Distribution'),
('l_eta', 'Lepton $\eta$', 'Lepton $\eta$ Distribution'),
('l_phi', 'Lepton $\phi$', 'Lepton $\phi$ Distribution'),
('l_mass', 'Lepton Mass (GeV)', 'Lepton Mass Distribution'),
('lbar_pt', 'Anti-Lepton $p_T$ (GeV)', 'Anti-Lepton $p_T$ Distribution'),
('lbar_eta', 'Anti-Lepton $\eta$', 'Anti-Lepton $\eta$ Distribution'),
('lbar_phi', 'Anti-Lepton $\phi$', 'Anti-Lepton $\phi$ Distribution'),
('lbar_mass', 'Anti-Lepton Mass (GeV)', 'Anti-Lepton Mass Distribution'),
('llbar_delta_phi', '$\Delta \phi_{ll}$', '$\Delta \phi_{ll}$ Distribution'),
('llbar_delta_eta', '$\Delta \eta_{ll}$', '$\Delta \eta_{ll}$ Distribution'),
('b1k', 'b1k', 'b1k'),
('b2k', 'b2k', 'b2k'),
('b1r', 'b1r', 'b1r'),
('b2r', 'b2r', 'b2r'),
('b1n', 'b1n', 'b1n'),
('b2n', 'b2n', 'b2n'),
('c_rk', 'c_rk', 'c_rk'),
('c_kr', 'c_kr', 'c_kr'),
('c_nr', 'c_nr', 'c_nr'),
('c_rn', 'c_rn', 'c_rn'),
('c_nk', 'c_nk', 'c_nk'),
('c_kn', 'c_kn', 'c_kn'),


#('gen_top_pt', 'Top $p_T$ (GeV)', 'Top $p_T$ Distribution'),
#('gen_top_phi', 'Top $\phi$', 'Top $\phi$ Distribution'),
#('gen_top_eta', 'Top $\eta$', 'Top $\eta$ Distribution'),
#('gen_top_mass', 'Top Mass (GeV)', 'Top Mass Distribution'),
#('gen_tbar_pt', 'Anti-Top $p_T$ (GeV)', 'Anti-Top $p_T$ Distribution'),
#('gen_tbar_phi', 'Anti-Top $\phi$', 'Anti-Top $\phi$ Distribution'),
#('gen_tbar_eta', 'Anti-Top $\eta$', 'Anti-Top $\eta$ Distribution'),
#('gen_tbar_mass', 'Anti-Top Mass (GeV)', 'Anti-Top Mass Distribution'),
#('gen_tbar_mass', 'Anti-Top Mass (GeV)', 'Anti-Top Mass Distribution'),
#('gen_l_pt', 'Lepton $p_T$ (GeV)', 'Lepton $p_T$ Distribution'),
#('gen_l_eta', 'Lepton $\eta$', 'Lepton $\eta$ Distribution'),
#('gen_l_phi', 'Lepton $\phi$', 'Lepton $\phi$ Distribution'),
#('gen_l_mass', 'Lepton Mass (GeV)', 'Lepton Mass Distribution'),
#('gen_lbar_pt', 'Anti-Lepton $p_T$ (GeV)', 'Anti-Lepton $p_T$ Distribution'),
#('gen_lbar_eta', 'Anti-Lepton $\eta$', 'Anti-Lepton $\eta$ Distribution'),
#('gen_lbar_phi', 'Anti-Lepton $\phi$', 'Anti-Lepton $\phi$ Distribution'),
#('gen_lbar_mass', 'Anti-Lepton Mass (GeV)', 'Anti-Lepton Mass Distribution'),
#('gen_llbar_delta_phi', '$\Delta \phi_{ll}$', '$\Delta \phi_{ll}$ Distribution'),
#('gen_llbar_delta_eta', '$\Delta \eta_{ll}$', '$\Delta \eta_{ll}$ Distribution'),
#('gen_b1k', 'gen_b1k', 'gen_b1k'),
#('gen_b2k', 'gen_b2k', 'gen_b2k'),
#('gen_b1r', 'gen_b1r', 'gen_b1r'),
#('gen_b2r', 'gen_b2r', 'gen_b2r'),
#('gen_b1n', 'gen_b1n', 'gen_b1n'),
#('gen_b2n', 'gen_b2n', 'gen_b2n'),
#('gen_c_rk', 'gen_c_rk', 'gen_c_rk'),
#('gen_c_kr', 'gen_c_kr', 'gen_c_kr'),
#('gen_c_nr', 'gen_c_nr', 'gen_c_nr'),
#('gen_c_rn', 'gen_c_rn', 'gen_c_rn'),
#('gen_c_nk', 'gen_c_nk', 'gen_c_nk'),
#'gen_c_kn', 'gen_c_kn', 'gen_c_kn'),
############################################################Gen level plot ####################################################

observables = {
    'gen_top_pt': file['gen_top_pt'],
    'gen_top_phi': file['gen_top_phi'],
    'gen_top_eta': file['gen_top_eta'],
    'gen_top_mass': file['gen_top_mass'],
    'gen_tbar_pt': file['gen_tbar_pt'],
    'gen_tbar_phi': file['gen_tbar_phi'],
    'gen_tbar_eta': file['gen_tbar_eta'],
    'gen_tbar_mass': file['gen_tbar_mass'],
    'gen_l_pt': file['gen_l_pt'],
    'gen_l_eta': file['gen_l_eta'],
    'gen_l_phi': file['gen_l_phi'],
    'gen_l_mass': file['gen_l_mass'],
    'gen_lbar_pt': file['gen_lbar_pt'],
    'gen_lbar_eta': file['gen_lbar_eta'],
    'gen_lbar_phi': file['gen_lbar_phi'],
    'gen_lbar_mass': file['gen_lbar_mass'],
    'gen_mttbar_mass': file['gen_ttbar_mass'],
    'gen_llbar_delta_phi': file['gen_llbar_delta_phi'],
    'gen_llbar_delta_eta': file['gen_llbar_delta_eta'],
    'gen_b1k': file['gen_b1k'],
    'gen_b2k': file['gen_b2k'],
    'gen_b1r': file['gen_b1r'],
    'gen_b2r': file['gen_b2r'],
    'gen_b1n': file['gen_b1n'],
    'gen_b2n': file['gen_b2n'],
    'gen_c_kk': file['gen_c_kk'],
    'gen_c_rr': file['gen_c_rr'],
    'gen_c_nn': file['gen_c_nn'],
    'gen_c_rk': file['gen_c_rk'],
    'gen_c_kr': file['gen_c_kr'],
    'gen_c_nr': file['gen_c_nr'],
    'gen_c_rn': file['gen_c_rn'],
    'gen_c_nk': file['gen_c_nk'],
    'gen_c_kn': file['gen_c_kn'],
    'gen_ll_cHel': file['gen_ll_cHel'],
    'gen_crk_ckr': file['gen_c_rk']+file['gen_c_kr'],
}

# List of observables to plot
observables_to_plot = {
    'gen_mttbar_mass': ('mttbar_mass', 'm_ttbar_mass'),
    'gen_c_kk': ('gen_c_kk', 'gen_c_kk'),
    'gen_c_rr': ('gen_c_rr', 'gen_c_rr'),
    'gen_c_nn': ('gen_c_nn', 'gen_c_nn'),
    'gen_ll_cHel': ('gen_$cos\phi$', 'gen_$cos\phi$'),
    'gen_crk_ckr': ('$c_{rk}+c_{kr}$', '$c_{rk}+c_{kr}$')
}

# Loop through and plot all observables
for obs_key, (xlabel, title) in observables_to_plot.items():
    plot_observables(observables[obs_key], xlabel, title, weights_dict)

# %%
import numpy as np
from uncertainties import ufloat

# Dictionary of observables
observables = {
    r'$C_{kk}$': file_jason['gen_c_kk'],
    r'$C_{rr}$': file_jason['gen_c_rr'],
    r'$C_{nn}$': file_jason['gen_c_nn']
}

# Define the weight array
weights = file_jason['trueLevelWeight']

# Define the constant multiplier
constant_factor = -4.0  # Replace this with the actual constant value

def assy(cosArr, weights):
    """Compute asymmetry A for a given observable array and weight."""
    N1 = ufloat(np.sum(weights[cosArr > 0]), np.sqrt(np.sum(weights[cosArr > 0]**2)))
    N2 = ufloat(np.sum(weights[cosArr < 0]), np.sqrt(np.sum(weights[cosArr < 0]**2)))
    return (N1 - N2) / (N1 + N2)

# Dictionary to store computed results
asymmetry_results = {}

# Compute asymmetry and parameter values for each observable
for obs_name, obs_data in observables.items():
    A = assy(obs_data, weights)  # Compute asymmetry
    param_value = constant_factor * A  # Compute parameter value
    asymmetry_results[obs_name] = { 'parameter value': param_value}

# Print results
for obs_name, values in asymmetry_results.items():
    print(f"{obs_name} = {values['parameter value'].nominal_value:.4f} ± {values['parameter value'].std_dev:.4f}")
# Out:
# $C_{kk}$ = 0.3056 ± 0.0023
# $C_{rr}$ = 0.0436 ± 0.0023
# $C_{nn}$ = 0.3180 ± 0.0023

# %%
# Define the range of Wilson coefficient ctGRe values
ctGRe_values = np.linspace(-0.5, 0.5, 9)

# Dictionary of observables
observables = {
    r'$C_{kk}$': file['gen_c_kk'],
    r'$C_{rr}$': file['gen_c_rr'],
    r'$C_{nn}$': file['gen_c_nn'],
    r'$C_{rk}+C_{kr}$': file['gen_c_rk'] + file['gen_c_kr'],
    r'$\frac{\Delta^{-}}{3}$': -(file['gen_c_kk'] + file['gen_c_rr'] + file['gen_c_nn'] + 1) / 3

}

# Dictionary to store mean cross-section differences for each observable
mean_xsec_differences_unbinned = {}

# Loop over each observable
for obs_name, observable_data in observables.items():
    sm_weight = np.array(weight_sm, dtype=np.float64)

    # Compute the unbinned mean for SM (weighted mean)
    mean_sm = 9*np.average(observable_data, weights=sm_weight)
    print(mean_sm)
    # Store mean differences for this observable
    mean_differences = []

    # Loop over ctGRe values
    for ctGRe in ctGRe_values:
        event_weights = np.array(predict_event_weight(ctGRe, 0), dtype=np.float64)

        # Compute unbinned weighted mean for ctGRe
        mean_ctGRe = 9*np.average(observable_data, weights=event_weights)
        print(mean_ctGRe)
        # Compute the difference
        diff = mean_ctGRe - mean_sm

        # Keep 5 decimal places
        mean_differences.append(diff)

    # Store results for this observable
    mean_xsec_differences_unbinned[obs_name] = mean_differences
# Out:
# -0.06296555074821278
# -0.08462716317611144
# -0.07961354465763902
# -0.0742958684572025
# -0.06872172909623996
# -0.06296555074821289
# -0.05713288174112226
# -0.05136260017973519
# -0.04582547072996145
# -0.04071752762142951
# 0.050478736613134484
# -0.06370438459956365
# -0.03687609049724701
# -0.008673801053081295
# 0.020595345480475823
# 0.0504787366131345
# 0.0803590838611282
# 0.10944792436646991
# 0.1367999728202564
# 0.16135580466232488
# -0.46994058633460395
# -0.6477507045797747
# -0.6059136452483845
# -0.56197069323688
# -0.5164084335692223
# -0.46994058633460417
# -0.42353740160958275
# -0.37843502258195033
# -0.3361121413842497
# -0.298222380204444
# 0.2617481158271499
# 0.26543463902782116
# 0.264567054485589
# 0.2636559115188257
# 0.2627113237577512
# 0.26174811582715
# 0.2607864312438844
# 0.2598519242355571
# 0.2589752727144927
# 0.25819077283103625
# -2.8391908678461166
# -2.7346392505237476
# -2.759198907847563
# -2.785019880406316
# -2.811821728933978
# ...

# %%
# Plot results
plt.figure(figsize=(10, 6))
for obs in observables:
    plt.plot(ctGRe_values, mean_xsec_differences_unbinned[obs], marker='o', linestyle='-', label=obs)

plt.xlabel(r"$c_{tGRe}$")
plt.ylabel(r"(Deviation from SM)")
#plt.title("Differential Cross-Section Deviation from SM")
plt.legend(loc='best', fontsize=13)
plt.grid()
plt.show()

# %%
# Define the range of Wilson coefficient ctGRe values
ctGRe_values = np.linspace(-0.5, 0.5, 9)

# Dictionary of observables
observables_reco = {
    r'$C_{kk}$': file['c_kk'],
    r'$C_{rr}$': file['c_rr'],
    r'$C_{nn}$': file['c_nn'],
    r'$C_{rk}+C_{kr}$': file['c_rk'] + file['c_kr'],
    r'$\frac{\Delta^{-}}{3}$': -(file['c_kk'] + file['c_rr'] + file['c_nn'] + 1) / 3

}

# Dictionary to store mean cross-section differences for each observable
mean_xsec_differences_unbinned_reco = {}

# Loop over each observable
for obs_name, observable_data in observables_reco.items():
    sm_weight = np.array(weight_sm, dtype=np.float64)

    # Compute the unbinned mean for SM (weighted mean)
    mean_sm = 9*np.average(observable_data, weights=sm_weight)
    print(mean_sm)
    # Store mean differences for this observable
    mean_differences = []

    # Loop over ctGRe values
    for ctGRe in ctGRe_values:
        event_weights = np.array(predict_event_weight(ctGRe, 0), dtype=np.float64)

        # Compute unbinned weighted mean for ctGRe
        mean_ctGRe = 9*np.average(observable_data, weights=event_weights)
        print(mean_ctGRe)
        # Compute the difference
        diff = mean_ctGRe - mean_sm

        # Keep 5 decimal places
        mean_differences.append(diff)

    # Store results for this observable
    mean_xsec_differences_unbinned_reco[obs_name] = mean_differences
# Out:
# -0.20895543270469874
# -0.24786565459737
# -0.2387998033060688
# -0.22922206620875227
# -0.21922636775051096
# -0.20895543270469885
# -0.1986079853820292
# -0.18844194298130953
# -0.17877081235147493
# -0.1699506344777837
# -0.06797324338896095
# -0.12267277638679146
# -0.10982739941206565
# -0.09631995635392726
# -0.08229663471700194
# -0.06797324338896099
# -0.05364446911379207
# -0.03968707590166939
# -0.026553143302253016
# -0.014749750388873648
# -0.8196869049762122
# -0.9575938551598018
# -0.9251410122585888
# -0.8910575125121624
# -0.8557213941818341
# -0.8196869049762125
# -0.783707260634262
# -0.7487418475824285
# -0.7159380396153795
# -0.6865786635067286
# 0.5096986826898747
# 0.534594444290921
# 0.5287351906576451
# 0.5225819489949365
# 0.5162030602772119
# 0.5096986826898753
# 0.5032048943197355
# 0.49689498473204197
# 0.4909761609851599
# 0.4856800505965718
# -2.6344614731612257
# -2.5572892381322383
# -2.5754105951890294
# -2.5944668218240663
# -2.6142518679669857
# ...

# %%
# Plot results
plt.figure(figsize=(10, 6))
for obs in observables_reco:
    plt.plot(ctGRe_values, mean_xsec_differences_unbinned_reco[obs], marker='o', linestyle='-', label=obs)

plt.xlabel(r"$c_{tGRe}$")
plt.ylabel(r"(Deviation from SM)")
#plt.title("Differential Cross-Section Deviation from SM")
plt.legend(loc='best', fontsize=13)
plt.grid()
plt.show()
